# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

kDepth = 50
loop = 10
guard = 10

filename = f"./pullUp_{kDepth}_{loop}_{guard}.csv"


df = pd.read_csv(filename, index_col=None, header=0)

# %%
df.loc[ df['Heuristics'] == True,]


df
# Out:
#     Validity  Heuristics  Loop depth  If depth   N  \
# 0      False        True          10        10   2
# 1      False        True          10        10   3
# 2      False        True          10        10   4
# 3      False        True          10        10   5
# 4      False        True          10        10   6
# 5      False        True          10        10   7
# 6      False        True          10        10   8
# 7      False        True          10        10   9
# 8      False        True          10        10  10
# 9      False       False          10        10   2
# 10     False       False          10        10   3
# 11     False       False          10        10   4
# 12     False       False          10        10   5
# 13     False       False          10        10   6
# 14     False       False          10        10   7
# 15     False       False          10        10   8
# 16     False       False          10        10   9
# ...

# %%
def plotfile(name, k,loop,guard,parameter):
    filename = f"./{name}_{k}_{loop}_{guard}.csv"
    df = pd.read_csv(filename, index_col=None, header=0)
    
    label = f'loop:{loop} guard:{guard}' 
    plt.plot('N', parameter, data=df.loc[ df['Heuristics'] == True,], linestyle='dashed', label=f"{label}")
    plt.plot('N', parameter, data=df.loc[ df['Heuristics'] == False,], label=f'{label}')

# %%
def plotTotalTime(name,k, loop,guard):
    plotfile(name,k,loop,guard, 'Total time')
    
def plotVerification(name,k,loop,guard):
    plotfile(name,k,loop,guard, 'Time spent on verification')
    
def plotUnfeasible(name,k,loop,guard):
    plotfile(name,k,loop,guard, 'Time spent on finding unfeasible paths')

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotTotalTime('pullUp',50,10,10)
plotTotalTime('pullUp',50,10,5)

plotTotalTime('pullUp',50,10,15)
plotTotalTime('pullUp',50,20,10)
plotTotalTime('pullUp',50,20,5)

plotTotalTime('pullUp',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plotTotalTime('pullUp',30,10,10)
plotTotalTime('pullUp',30,10,5)

plotTotalTime('pullUp',30,10,15)
plotTotalTime('pullUp',30,20,10)
plotTotalTime('pullUp',30,20,5)

plotTotalTime('pullUp',30,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plotVerification('pullUp',50,10,10)
plotVerification('pullUp',50,10,5)

plotVerification('pullUp',50,10,15)
plotVerification('pullUp',50,20,10)
plotVerification('pullUp',50,20,5)

plotVerification('pullUp',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotTotalTime('memberOf',50,10,10)
plotTotalTime('memberOf',50,10,5)

plotTotalTime('memberOf',50,10,15)
plotTotalTime('memberOf',50,20,10)
plotTotalTime('memberOf',50,20,5)

plotTotalTime('memberOf',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotTotalTime('memberOf',50,10,10)
plotTotalTime('memberOf',50,10,5)

plotTotalTime('memberOf',50,10,15)
plotTotalTime('memberOf',50,20,10)
plotTotalTime('memberOf',50,20,5)

plotTotalTime('memberOf',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotUnfeasible('memberOf',50,10,10)
plotUnfeasible('memberOf',50,10,5)

plotUnfeasible('memberOf',50,10,15)
plotUnfeasible('memberOf',50,20,10)
plotUnfeasible('memberOf',50,20,5)

plotUnfeasible('memberOf',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plotVerification('memberOf',50,10,10)
plotVerification('memberOf',50,10,5)

plotVerification('memberOf',50,10,15)
plotVerification('memberOf',50,20,10)
plotVerification('memberOf',50,20,5)

plotVerification('memberOf',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotUnfeasible('memberOf',50,10,10)
plotUnfeasible('memberOf',50,10,5)

plotUnfeasible('memberOf',50,10,15)
plotUnfeasible('memberOf',50,20,10)
plotUnfeasible('memberOf',50,20,5)

plotUnfeasible('memberOf',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotUnfeasible('pullUp',50,10,10)
plotUnfeasible('pullUp',50,10,5)

plotUnfeasible('pullUp',50,10,15)
plotUnfeasible('pullUp',50,20,10)
plotUnfeasible('pullUp',50,20,5)

plotUnfeasible('pullUp',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotTotalTime('divByN',50,10,10)
plotTotalTime('divByN',50,10,5)

plotTotalTime('divByN',50,10,15)
plotTotalTime('divByN',50,20,10)
plotTotalTime('divByN',50,20,5)

plotTotalTime('divByN',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
plt.figure(figsize=[6.4, 4.8],dpi=150)
plt.xlabel('N value')
plt.ylabel('time in seconds')
plotUnfeasible('divByN',50,10,10)
plotUnfeasible('divByN',50,10,5)

plotUnfeasible('divByN',50,10,15)
plotUnfeasible('divByN',50,20,10)
plotUnfeasible('divByN',50,20,5)

plotUnfeasible('divByN',50,20,15)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
test = df.loc[ df['Heuristics'] == True,]

plt.plot('N', 'Time spent on verification', data=df.loc[ df['Heuristics'] == True,] )
plt.plot('N', 'Time spent on verification', data=df.loc[ df['Heuristics'] == False,] )
plt.legend()
plt.show()

# %%
plt.show()
